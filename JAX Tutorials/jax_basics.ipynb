# %%
import jax
import jax.numpy as jnp

# %%
key = jax.random.key(42)
W = jax.random.normal(key, (3, 3))
print(f"Weight Matrix = {W}")

W2 = jax.random.normal(key, (2, 2))
print(f"Another Weight Matrix = {W2}")
# Out:
# Weight Matrix = [[-0.02830462  0.46713185  0.29570296]
#  [ 0.15354592 -0.12403282  0.21692315]
#  [-1.4408789   0.7558599   0.52140963]]
# Another Weight Matrix = [[-0.02830462  0.46713185]
#  [ 0.29570296  0.15354592]]
